# %%
import sys
sys.path.append('..')

from plotter import Plotter

# %%
plotter = Plotter()

# %%
serial_kde = plotter.read_csv_file('../data/serial.csv')
cuda_kde = plotter.read_csv_file('../data/cuda.csv')
mpi_kde = plotter.read_csv_file('../data/mpi.csv')

# %%
plotter.plot_kde(serial_kde, "Serial Implementation", hist=True, rug=True, kde=True)

# %%
plotter.plot_kde(cuda_kde, "Cuda Implementation", hist=True, rug=True, kde=True)

# %%
plotter.plot_kde(mpi_kde, "MPI Implementation", hist=True, rug=True, kde=True)
